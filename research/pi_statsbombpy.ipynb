# %%
# !pip install statsbombpy

# %%
from statsbombpy import sb
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 100)
# pd.set_option('display.max_rows', 100)
pd.set_option("max_colwidth", 200)

# %%
sb.competitions()
# Out:
# /Users/pivan/virtual/fa/lib/python3.7/site-packages/statsbombpy/api_client.py:22: NoAuthWarning: credentials were not supplied. open data access only
#   "credentials were not supplied. open data access only", NoAuthWarning
#     competition_id  season_id   country_name    competition_name  \
# 0                9         27        Germany       1. Bundesliga
# 1               16          4         Europe    Champions League
# 2               16          1         Europe    Champions League
# 3               16          2         Europe    Champions League
# 4               16         27         Europe    Champions League
# ..             ...        ...            ...                 ...
# 65              55         43         Europe           UEFA Euro
# 66              35         75         Europe  UEFA Europa League
# 67              53        106         Europe   UEFA Women's Euro
# 68              72        107  International   Women's World Cup
# ...

# %%
def get_num_matches(x):
    try:
        num_ = sb.matches(x['competition_id'], x['season_id']).shape[0]
    except:
        num_ = np.nan
    return num_


df_competitions = sb.competitions()
df_competitions['num_matches'] = df_competitions.apply(lambda x: get_num_matches(x), axis=1)
df_competitions['season_name_id'] = df_competitions[['season_name', 'season_id']].apply(tuple, axis=1)

df_competitions.groupby(['competition_gender', 'competition_international', 'competition_id', 'country_name', 'competition_name'])\
['season_name_id'].apply(list).reset_index().sort_values(['competition_gender', 'country_name'])
# Out:
# /Users/pivan/virtual/fa/lib/python3.7/site-packages/statsbombpy/api_client.py:22: NoAuthWarning: credentials were not supplied. open data access only
#   "credentials were not supplied. open data access only", NoAuthWarning
#    competition_gender  competition_international  competition_id  \
# 0              female                      False              37
# 2              female                       True              53
# 3              female                       True              72
# 1              female                      False              49
# 12               male                      False              81
# 4                male                      False               2
# 9                male                      False              16
# 10               male                      False              35
# 18               male                       True              55
# 5                male                      False               7
# ...

# %%
df_competitions.sort_values('num_matches', ascending=False)[:40]
# Out:
#     competition_id  season_id              country_name  \
# 63              12         27                     Italy
# 61               2         27                   England
# 40              11         27                     Spain
# 0                9         27                   Germany
# 22              37         90                   England
# 34            1238        108                     India
# 24              37          4                   England
# 23              37         42                   England
# 68              72        107             International
# 27              43          3             International
# 26              43        106             International
# 69              72         30             International
# 65              55         43                    Europe
# 41              11         26                     Spain
# 62               2         44                   England
# 44              11         23                     Spain
# ...

# %%
df_competitions[df_competitions['match_available_360'].notna()].sort_values('num_matches', ascending=False)
# Out:
#     competition_id  season_id              country_name     competition_name  \
# 26              43        106             International       FIFA World Cup
# 68              72        107             International    Women's World Cup
# 65              55         43                    Europe            UEFA Euro
# 35              11         90                     Spain              La Liga
# 55               7        235                    France              Ligue 1
# 67              53        106                    Europe    UEFA Women's Euro
# 56               7        108                    France              Ligue 1
# 58              44        107  United States of America  Major League Soccer
#
#    competition_gender  competition_youth  competition_international  \
# 26               male              False                       True
# 68             female              False                       True
# 65               male              False                       True
# ...

# %%
sb.matches(competition_id=55, season_id=43).sort_values('match_date').head()
# Out:
# /Users/pivan/virtual/fa/lib/python3.7/site-packages/statsbombpy/api_client.py:22: NoAuthWarning: credentials were not supplied. open data access only
#   "credentials were not supplied. open data access only", NoAuthWarning
#     match_id  match_date      kick_off         competition season home_team  \
# 12   3788741  2021-06-11  21:00:00.000  Europe - UEFA Euro   2020    Turkey
# 50   3788744  2021-06-12  15:00:00.000  Europe - UEFA Euro   2020     Wales
# 49   3788743  2021-06-12  21:00:00.000  Europe - UEFA Euro   2020   Belgium
# 46   3788742  2021-06-12  18:00:00.000  Europe - UEFA Euro   2020   Denmark
# 33   3788745  2021-06-13  15:00:00.000  Europe - UEFA Euro   2020   England
#
#       away_team  home_score  away_score match_status match_status_360  \
# 12        Italy           0           3    available        available
# 50  Switzerland           1           1    available        available
# 49       Russia           3           0    available        available
# ...

# %%
event_id = 3788746
sb.lineups(match_id=event_id)["Ukraine"]
# Out:
# /Users/pivan/virtual/fa/lib/python3.7/site-packages/statsbombpy/api_client.py:22: NoAuthWarning: credentials were not supplied. open data access only
#   "credentials were not supplied. open data access only", NoAuthWarning
#     player_id           player_name   player_nickname  jersey_number  country  \
# 0        3575   Oleksandr Zinchenko              None             17  Ukraine
# 1        4872          Eduard Sobol              None              2  Ukraine
# 2        8830     Andriy Yarmolenko              None              7  Ukraine
# 3       10997         Andriy Pyatov              None             12  Ukraine
# 4       11000      Taras Stepanenko              None              6  Ukraine
# 5       16311      Evgeny Makarenko              None             14  Ukraine
# 6       16514      Serhii Sydorchuk  Sergiy Sydorchuk              5  Ukraine
# 7       16557    Ruslan Malinovskiy              None              8  Ukraine
# ...

# %%
sb.events(match_id=event_id)
# Out:
# /Users/pivan/virtual/fa/lib/python3.7/site-packages/statsbombpy/api_client.py:22: NoAuthWarning: credentials were not supplied. open data access only
#   "credentials were not supplied. open data access only", NoAuthWarning
#      ball_receipt_outcome ball_recovery_recovery_failure block_deflection  \
# 0                     NaN                            NaN              NaN
# 1                     NaN                            NaN              NaN
# 2                     NaN                            NaN              NaN
# 3                     NaN                            NaN              NaN
# 4                     NaN                            NaN              NaN
# ...                   ...                            ...              ...
# 3964                  NaN                            NaN              NaN
# 3965                  NaN                            NaN              NaN
# 3966                  NaN                            NaN              NaN
# ...

# %%
sb.events(match_id=event_id)['type'].value_counts()
# Out:
# /Users/pivan/virtual/fa/lib/python3.7/site-packages/statsbombpy/api_client.py:22: NoAuthWarning: credentials were not supplied. open data access only
#   "credentials were not supplied. open data access only", NoAuthWarning
# Pass                 1154
# Ball Receipt*        1125
# Carry                 940
# Pressure              347
# Ball Recovery          79
# Duel                   55
# Block                  30
# Dispossessed           29
# Clearance              25
# Goal Keeper            25
# Miscontrol             24
# Interception           22
# Shot                   22
# Dribble                21
# Foul Committed         19
# Foul Won               17
# Dribbled Past          14
# Substitution            7
# Half Start              4
# Half End                4
# Shield                  2
# Starting XI             2
# Referee Ball-Drop       1
# Error                   1
# Name: type, dtype: int64

# %%
sb.events(match_id=event_id, split=True).keys()
# Out:
# dict_keys(['starting_xis', 'half_starts', 'passes', 'ball_receipts', 'carrys', 'pressures', 'blocks', 'miscontrols', 'duels', 'ball_recoverys', 'interceptions', 'dribbled_pasts', 'dribbles', 'shots', 'goal_keepers', 'clearances', 'dispossesseds', 'foul_committeds', 'foul_wons', 'substitutions', 'referee_ball_drops', 'shields', 'half_ends', 'errors'])

# %%
sb.events(match_id=event_id, split=True)["half_starts"]
# Out:
# /Users/pivan/virtual/fa/lib/python3.7/site-packages/statsbombpy/api_client.py:22: NoAuthWarning: credentials were not supplied. open data access only
#   "credentials were not supplied. open data access only", NoAuthWarning
#                                      id  index  period     timestamp  minute  \
# 0  c81ff888-b3e9-4789-b134-bff90a9818b3      3       1  00:00:00.000       0
# 1  e03eb18e-efef-4e99-aea8-8a6132ef1fa1      4       1  00:00:00.000       0
# 2  353e7334-92b0-44b0-8112-d76affa0fcc5   2066       2  00:00:00.000      45
# 3  36eec752-f38f-4f7a-9d7d-c863c4e12d51   2067       2  00:00:00.000      45
#
#    second        type  possession possession_team  play_pattern         team  \
# 0       0  Half Start           1     Netherlands  Regular Play  Netherlands
# 1       0  Half Start           1     Netherlands  Regular Play      Ukraine
# 2       0  Half Start          85         Ukraine  Regular Play  Netherlands
# ...

# %%
# pd.read_json('3906390.json')

# %%
# match_frames = sb.frames(match_id=event_id, fmt='dict')

match_frames = sb.frames(match_id=event_id, fmt='dataframe')
match_frames
# Out:
#                                          id  \
# 0      e7e64ca3-3420-4be1-aaea-b48f217d41cb
# 1      e7e64ca3-3420-4be1-aaea-b48f217d41cb
# 2      e7e64ca3-3420-4be1-aaea-b48f217d41cb
# 3      e7e64ca3-3420-4be1-aaea-b48f217d41cb
# 4      e7e64ca3-3420-4be1-aaea-b48f217d41cb
# ...                                     ...
# 56202  d1679bbe-bbce-4b34-bfe4-a64c628a781c
# 56203  d1679bbe-bbce-4b34-bfe4-a64c628a781c
# 56204  d1679bbe-bbce-4b34-bfe4-a64c628a781c
# 56205  d1679bbe-bbce-4b34-bfe4-a64c628a781c
# 56206  d1679bbe-bbce-4b34-bfe4-a64c628a781c
#
#                                                                                                                                          visible_area  \
# 0      [120.0, 20.8977381982129, 83.502489488547, 80.0, 35.9442992882804, 80.0, 0.0, 25.4472154431588, 0.0, 0.0, 120.0, 0.0, 120.0, 20.8977381982129]
# ...
