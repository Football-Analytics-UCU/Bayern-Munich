# %% [markdown]
# https://github.com/probberechts/soccerdata

# %%
! git clone https://github.com/probberechts/soccerdata.git
# Out:
# Cloning into 'soccerdata'...
# remote: Enumerating objects: 2196, done.
# remote: Counting objects: 100% (1018/1018), done.
# remote: Compressing objects: 100% (381/381), done.
# remote: Total 2196 (delta 707), reused 786 (delta 624), pack-reused 1178
# Receiving objects: 100% (2196/2196), 2.63 MiB | 4.43 MiB/s, done.
# Resolving deltas: 100% (1300/1300), done.

# %%
! pip install soccerdata
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.0/43.0 kB 1.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.6/240.6 kB 3.1 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 11.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.4/65.4 kB 5.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 7.4 MB/s eta 0:00:0000:0100:01
# ...
#   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 7.8 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 8.1 MB/s eta 0:00:0000:010:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 461.6/461.6 kB 8.9 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.1 MB/s eta 0:00:00
# ...

# %%
import soccerdata as sd

# %% [markdown]
# # Sources

# %% [markdown]
# - [FiveThirtyEight](#FiveThirtyEight)
# - [ClubElo](#Elo)
# - [MatchHistory](#MatchHistory)
# - [FBref](#FBref)
# - [ESPN](#ESPN)
# - [WhoScored](#WhoScored)
# - [SoFIFA](#SoFIFA)

# %% [markdown]
# <a id='FiveThirtyEight'></a>
# ## 1. FiveThirtyEight

# %% [markdown]
# Doc: https://soccerdata.readthedocs.io/en/latest/datasources/FiveThirtyEight.html

# %% [markdown]
# http://abcnews.go.com/538

# %% [markdown]
# https://en.wikipedia.org/wiki/FiveThirtyEight

# %%
# Create a scraper class instance for the 2018/19 Premier League
five38 = sd.FiveThirtyEight('ENG-Premier League', '1819')

# Fetch data
games = five38.read_games()
forecasts = five38.read_forecasts()
clinches = five38.read_clinches()
# Out:
# [12/22/23 18:49:16] INFO     Saving cached data to /Users/maksym/soccerdata/data/FiveThirtyEight      ]8;id=188104;file:///Users/maksym/anaconda3/lib/python3.10/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=541194;file:///Users/maksym/anaconda3/lib/python3.10/site-packages/soccerdata/_common.py#91\91]8;;\

# %%
print(five38.__doc__)
# Out:
# Provides pd.DataFrames from FiveThirtyEight's "Club Soccer Predictions" project.
#
#     Data will be downloaded as necessary and cached locally in
#     ``~/soccerdata/data/FiveThirtyEight``.
#
#     Original project and background info:
#     https://projects.fivethirtyeight.com/soccer-predictions/ and
#     https://fivethirtyeight.com/features/how-our-club-soccer-projections-work/
#
#
#     Parameters
#     ----------
#     leagues : string or iterable, optional
#         IDs of leagues to include.
#     seasons : string, int or list, optional
#         Seasons to include. Supports multiple formats.
#         Examples: '16-17'; 2016; '2016-17'; [14, 15, 16]
#     proxy : 'tor' or dict or list(dict) or callable, optional
#         Use a proxy to hide your IP address. Valid options are:
#             - "tor": Uses the Tor network. Tor should be running in
#               the background on port 9050.
#             - dict: A dictionary with the proxy to use. The dict should be
# ...

# %%
games.head(2)
# Out:
#                                                                                            date  \
# league             season game
# ENG-Premier League 1819   2018-08-10 Manchester United-Leicester City 2018-08-10 19:00:00+00:00
#                           2018-08-11 AFC Bournemouth-Cardiff City     2018-08-11 14:00:00+00:00
#
#                                                                       status  \
# league             season game
# ENG-Premier League 1819   2018-08-10 Manchester United-Leicester City   post
#                           2018-08-11 AFC Bournemouth-Cardiff City       post
#
#                                                                         leg  \
# league             season game
# ENG-Premier League 1819   2018-08-10 Manchester United-Leicester City  None
#                           2018-08-11 AFC Bournemouth-Cardiff City      None
#
#                                                                                home_team  \
# ...

# %%
games.columns
# Out:
# Index(['date', 'status', 'leg', 'home_team', 'away_team', 'home_id', 'away_id',
#        'home_code', 'away_code', 'prob_home', 'prob_away', 'prob_tie', 'round',
#        'score_home', 'score_away', 'adj_score_home', 'adj_score_away',
#        'chances_home', 'chances_away', 'moves_home', 'moves_away',
#        'aggregate_winner', 'shootout_winner'],
#       dtype='object')

# %%
forecasts
# Out:
#                                                                             code  \
# league             season last_updated             team
# ENG-Premier League 1819   2018-08-10T14:00:15.687Z AFC Bournemouth           BOU
#                                                    Arsenal                   ARS
#                                                    Brighton and Hove Albion  BHA
#                                                    Burnley                   BRN
#                                                    Cardiff City              CAR
# ...                                                                          ...
#                           2019-06-01T21:02:15.533Z Southampton               SOU
#                                                    Tottenham Hotspur         TOT
#                                                    Watford                   WAT
#                                                    West Ham United           WHU
# ...

# %% [markdown]
# <a id='Elo'></a>
# ## 2. Elo

# %% [markdown]
# Doc: https://soccerdata.readthedocs.io/en/latest/datasources/ClubElo.html

# %% [markdown]
# http://clubelo.com/

# %% [markdown]
# https://en.wikipedia.org/wiki/Elo_rating_system

# %%
elo = sd.ClubElo()
# Out:
# [12/22/23 16:39:02] INFO     Saving cached data to /Users/maksym/soccerdata/data/ClubElo              ]8;id=328651;file:///Users/maksym/anaconda3/lib/python3.10/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=867539;file:///Users/maksym/anaconda3/lib/python3.10/site-packages/soccerdata/_common.py#91\91]8;;\

# %%
print(elo.__doc__)
# Out:
# Provides pd.DataFrames from CSV API at http://api.clubelo.com.
#
#     Data will be downloaded as necessary and cached locally in
#     ``~/soccerdata/data/ClubElo``.
#
#     Since the source does not provide league names, this class will not filter
#     by league. League names will be inserted from the other sources where
#     available. Leagues that are only covered by clubelo.com will have NaN
#     values.
#
#     Parameters
#     ----------
#     proxy : 'tor' or dict or list(dict) or callable, optional
#         Use a proxy to hide your IP address. Valid options are:
#             - "tor": Uses the Tor network. Tor should be running in
#               the background on port 9050.
#             - dict: A dictionary with the proxy to use. The dict should be
#               a mapping of supported protocols to proxy addresses. For example::
#
#                   {
#                       'http': 'http://10.10.1.10:3128',
#                       'https': 'http://10.10.1.10:1080',
# ...

# %%
current_elo = elo.read_by_date()
current_elo.head()
# Out:
# /Users/maksym/anaconda3/lib/python3.10/site-packages/soccerdata/clubelo.py:18: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   return pd.read_csv(
#              rank country  level          elo       from         to  \
# team
# Man City      1.0     ENG      1  2037.246216 2023-12-17 2023-12-27
# Real Madrid   2.0     ESP      1  1965.325195 2023-12-22 2023-12-30
# Bayern        3.0     GER      1  1959.342651 2023-12-21 2023-12-30
# Arsenal       4.0     ENG      1  1939.389771 2023-12-18 2023-12-23
# Inter         5.0     ITA      1  1936.872559 2023-12-18 2023-12-23
#
#                          league
# team
# Man City     ENG-Premier League
# Real Madrid         ESP-La Liga
# Bayern           GER-Bundesliga
# Arsenal      ENG-Premier League
# ...

# %%
current_elo = elo.read_by_date("2023-12-17")
current_elo.head()
# Out:
# /Users/maksym/anaconda3/lib/python3.10/site-packages/soccerdata/clubelo.py:18: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   return pd.read_csv(
#              rank country  level          elo       from         to  \
# team
# Man City      1.0     ENG      1  2037.246216 2023-12-17 2023-12-27
# Real Madrid   2.0     ESP      1  1962.239380 2023-12-15 2023-12-17
# Bayern        3.0     GER      1  1955.870239 2023-12-15 2023-12-17
# Liverpool     4.0     ENG      1  1941.274414 2023-12-15 2023-12-17
# Arsenal       5.0     ENG      1  1933.900269 2023-12-15 2023-12-17
#
#                          league
# team
# Man City     ENG-Premier League
# Real Madrid         ESP-La Liga
# Bayern           GER-Bundesliga
# Liverpool    ENG-Premier League
# ...

# %%
barca_elo = elo.read_team_history("Bayern")
barca_elo
# Out:
# /Users/maksym/anaconda3/lib/python3.10/site-packages/soccerdata/clubelo.py:18: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   return pd.read_csv(
#             rank    team country  level          elo         to
# from
# 1951-07-01   NaN  Bayern     FRG      1  1357.176392 1951-08-19
# 1951-08-20   NaN  Bayern     FRG      1  1364.539307 1951-08-26
# 1951-08-27   NaN  Bayern     FRG      1  1367.208374 1951-09-02
# 1951-09-03   NaN  Bayern     FRG      1  1349.025024 1951-09-09
# 1951-09-10   NaN  Bayern     FRG      1  1344.116333 1951-09-16
# ...          ...     ...     ...    ...          ...        ...
# 2023-12-14   2.0  Bayern     GER      1  1964.581543 2023-12-14
# 2023-12-15   3.0  Bayern     GER      1  1955.870239 2023-12-17
# ...

# %% [markdown]
# <a id='MatchHistory'></a>
# ## 3. MatchHistory

# %% [markdown]
# Doc: https://soccerdata.readthedocs.io/en/latest/datasources/MatchHistory.html

# %% [markdown]
# http://www.football-data.co.uk

# %%
mh = sd.MatchHistory()
# Out:
# [12/22/23 16:50:45] INFO     Saving cached data to /Users/maksym/soccerdata/data/MatchHistory         ]8;id=580718;file:///Users/maksym/anaconda3/lib/python3.10/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=655112;file:///Users/maksym/anaconda3/lib/python3.10/site-packages/soccerdata/_common.py#91\91]8;;\
#                     INFO     No seasons provided. Will retrieve data for the last 5 seasons.         ]8;id=63994;file:///Users/maksym/anaconda3/lib/python3.10/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=682506;file:///Users/maksym/anaconda3/lib/python3.10/site-packages/soccerdata/_common.py#290\290]8;;\

# %%
print(mh.__doc__)
# Out:
# Provides pd.DataFrames from CSV files available at http://www.football-data.co.uk/data.php.
#
#     Data will be downloaded as necessary and cached locally in
#     ``~/soccerdata/data/MatchHistory``.
#
#     Parameters
#     ----------
#     leagues : string or iterable
#         IDs of leagues to include.
#     seasons : string, int or list
#         Seasons to include. Supports multiple formats.
#         Examples: '16-17'; 2016; '2016-17'; [14, 15, 16]
#     proxy : 'tor' or dict or list(dict) or callable, optional
#         Use a proxy to hide your IP address. Valid options are:
#             - "tor": Uses the Tor network. Tor should be running in
#               the background on port 9050.
#             - dict: A dictionary with the proxy to use. The dict should be
#               a mapping of supported protocols to proxy addresses. For example::
#
#                   {
#                       'http': 'http://10.10.1.10:3128',
# ...

# %%
hist = mh.read_games()
hist.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 hist = mh.read_games()
#       2 hist.head()
#
# File ~/anaconda3/lib/python3.10/site-packages/soccerdata/match_history.py:106, in MatchHistory.read_games(self)
#     102     df_games["Time"] = df_games["Time"].fillna("12:00")
#     103     df_list.append(df_games)
#     105 df = (
# --> 106     pd.concat(df_list, sort=False)
#     107     .rename(columns=col_rename)
#     108     .assign(
#     109         date=lambda x: pd.to_datetime(x["date"] + ' ' + x['time'], format="%d/%m/%Y %H:%M")
#     110     )
#     111     .drop("time", axis=1)
#     112     .pipe(self._translate_league)
#     113     .replace(
#     114         {
#     115             'home_team': TEAMNAME_REPLACEMENTS,
#     116             'away_team': TEAMNAME_REPLACEMENTS,
#     117         }
#     118     )
# ...

# %% [markdown]
# <a id='FBref'></a>
# ## 4. FBref

# %% [markdown]
# Doc: https://soccerdata.readthedocs.io/en/latest/datasources/FBref.html

# %% [markdown]
# http://fbref.com

# %%
fbref = sd.FBref(leagues="ENG-Premier League", seasons=2021)
print(fbref.__doc__)
# Out:
# [12/22/23 16:59:46] INFO     Saving cached data to /Users/maksym/soccerdata/data/FBref                ]8;id=175475;file:///Users/maksym/anaconda3/lib/python3.10/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=50704;file:///Users/maksym/anaconda3/lib/python3.10/site-packages/soccerdata/_common.py#91\91]8;;\
# Provides pd.DataFrames from data at http://fbref.com.
#
#     Data will be downloaded as necessary and cached locally in
#     ``~/soccerdata/data/FBref``.
#
#     Parameters
#     ----------
#     leagues : string or iterable, optional
#         IDs of leagues to include. For efficiently reading data from the Top-5
#         European leagues, use "Big 5 European Leagues Combined".
#     seasons : string, int or list, optional
#         Seasons to include. Supports multiple formats.
#         Examples: '16-17'; 2016; '2016-17'; [14, 15, 16]
#     proxy : 'tor' or dict or list(dict) or callable, optional
#         Use a proxy to hide your IP address. Valid options are:
# ...

# %% [markdown]
# <a id='ESPN'></a>
# ## 5. ESPN

# %% [markdown]
# Doc: https://soccerdata.readthedocs.io/en/latest/datasources/ESPN.html

# %% [markdown]
# https://en.wikipedia.org/wiki/ESPN

# %% [markdown]
# https://www.espn.com/

# %%
espn = sd.ESPN(leagues="ENG-Premier League", seasons=2021)
print(espn.__doc__)
# Out:
# [12/22/23 17:01:34] INFO     Saving cached data to /Users/maksym/soccerdata/data/ESPN                 ]8;id=863402;file:///Users/maksym/anaconda3/lib/python3.10/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=756688;file:///Users/maksym/anaconda3/lib/python3.10/site-packages/soccerdata/_common.py#91\91]8;;\
# Provides pd.DataFrames from JSON api available at http://site.api.espn.com.
#
#     Data will be downloaded as necessary and cached locally in
#     ``~/soccerdata/data/ESPN``.
#
#     Parameters
#     ----------
#     leagues : string or iterable, optional
#         IDs of leagues to include.
#     seasons : string, int or list, optional
#         Seasons to include. Supports multiple formats.
#         Examples: '16-17'; 2016; '2016-17'; [14, 15, 16]
#     proxy : 'tor' or dict or list(dict) or callable, optional
#         Use a proxy to hide your IP address. Valid options are:
#             - "tor": Uses the Tor network. Tor should be running in
# ...

# %% [markdown]
# Game schedule

# %%
epl_schedule = espn.read_schedule()
epl_schedule.head()
# Out:
#                                                                                            date  \
# league             season game
# ENG-Premier League 2021   2019-08-09 Liverpool-Norwich City           2019-08-09 19:00:00+00:00
#                           2019-08-10 AFC Bournemouth-Sheffield United 2019-08-10 14:00:00+00:00
#                           2019-08-10 Burnley-Southampton              2019-08-10 14:00:00+00:00
#                           2019-08-10 Crystal Palace-Everton           2019-08-10 14:00:00+00:00
#                           2019-08-10 Tottenham Hotspur-Aston Villa    2019-08-10 16:30:00+00:00
#
#                                                                                home_team  \
# league             season game
# ENG-Premier League 2021   2019-08-09 Liverpool-Norwich City                    Liverpool
#                           2019-08-10 AFC Bournemouth-Sheffield United    AFC Bournemouth
# ...

# %%
matchsheet = espn.read_matchsheet(match_id=541844)
matchsheet.head()
# Out:
#                                                                           is_home  \
# league             season game                              team
# ENG-Premier League 2021   2019-08-09 Liverpool-Norwich City Liverpool        True
#                                                             Norwich City    False
#
#                                                                          venue  \
# league             season game                              team
# ENG-Premier League 2021   2019-08-09 Liverpool-Norwich City Liverpool     None
#                                                             Norwich City  None
#
#                                                                           attendance  \
# league             season game                              team
# ENG-Premier League 2021   2019-08-09 Liverpool-Norwich City Liverpool          53333
#                                                             Norwich City       53333
#
# ...

# %%
lineups = espn.read_lineup(match_id=541844)
lineups
# Out:
#                                                                                                   is_home  \
# league             season game                              team         player
# ENG-Premier League 2021   2019-08-09 Liverpool-Norwich City Liverpool    Adrián                      True
#                                                                          Alex Oxlade-Chamberlain     True
#                                                                          Alisson Becker              True
#                                                                          Andy Robertson              True
#                                                                          Divock Origi                True
#                                                                          Fabinho                     True
#                                                                          Georginio Wijnaldum         True
# ...

# %% [markdown]
# <a id='WhoScored'></a>
# ## 6. WhoScored

# %% [markdown]
# Doc: https://soccerdata.readthedocs.io/en/latest/datasources/WhoScored.html

# %%
ws = sd.WhoScored(leagues="ENG-Premier League", seasons=2021)
print(ws.__doc__)
# Out:
# [12/22/23 17:16:26] INFO     Saving cached data to /Users/maksym/soccerdata/data/WhoScored            ]8;id=533805;file:///Users/maksym/anaconda3/lib/python3.10/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=373387;file:///Users/maksym/anaconda3/lib/python3.10/site-packages/soccerdata/_common.py#91\91]8;;\
# [12/22/23 17:16:27] INFO     patching driver executable /Users/maksym/Library/Application            ]8;id=837937;file:///Users/maksym/anaconda3/lib/python3.10/site-packages/undetected_chromedriver/patcher.py\patcher.py]8;;\:]8;id=456735;file:///Users/maksym/anaconda3/lib/python3.10/site-packages/undetected_chromedriver/patcher.py#346\346]8;;\
#                              Support/undetected_chromedriver/undetected_chromedriver
# Provides pd.DataFrames from data available at http://whoscored.com.
#
#     Data will be downloaded as necessary and cached locally in
#     ``~/soccerdata/data/WhoScored``.
#
#     Parameters
#     ----------
# ...

# %%
epl_schedule = ws.read_schedule()
epl_schedule.head()
# Out:
# [12/22/23 17:19:05] ERROR    Error while scraping https://www.whoscored.com. Retrying... (attempt 1  ]8;id=199932;file:///Users/maksym/anaconda3/lib/python3.10/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=562210;file:///Users/maksym/anaconda3/lib/python3.10/site-packages/soccerdata/_common.py#457\457]8;;\
#                              of 5).
#                              Traceback (most recent call last):
#                                File
#                              "/Users/maksym/anaconda3/lib/python3.10/site-packages/soccerdata/_commo
#                              n.py", line 437, in _download_and_save
#                                  self._driver.get(url)
#                                File
#                              "/Users/maksym/anaconda3/lib/python3.10/site-packages/undetected_chrome
#                              driver/__init__.py", line 665, in get
#                                  return super().get(url)
# ...

# %% [markdown]
# <a id='SoFIFA'></a>
# ## 7. SoFIFA

# %% [markdown]
# http://sofifa.com

# %% [markdown]
# Doc: https://soccerdata.readthedocs.io/en/latest/datasources/SoFIFA.html

# %%
sofifa = sd.SoFIFA(leagues="ENG-Premier League", versions="latest")
print(sofifa.__doc__)
# Out:
# [12/22/23 17:23:12] INFO     Saving cached data to /Users/maksym/soccerdata/data/SoFIFA               ]8;id=697882;file:///Users/maksym/anaconda3/lib/python3.10/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=439361;file:///Users/maksym/anaconda3/lib/python3.10/site-packages/soccerdata/_common.py#91\91]8;;\
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 sofifa = sd.SoFIFA(leagues="ENG-Premier League", versions="latest")
#       2 print(sofifa.__doc__)
#
# File ~/anaconda3/lib/python3.10/site-packages/soccerdata/sofifa.py:80, in SoFIFA.__init__(self, leagues, versions, proxy, no_cache, no_store, data_dir)
#      78 self.rate_limit = 1
#      79 if versions == "latest":
# ---> 80     self.versions = self.read_versions().tail(n=1)
#      81 elif versions == "all":
#      82     self.versions = self.read_versions()
#
# ...

# %% [markdown]
# # https://opensource.pysport.org/?languages=Python&sports=Soccer
